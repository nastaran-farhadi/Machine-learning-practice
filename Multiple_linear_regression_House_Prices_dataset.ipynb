# %% [markdown]
# <a href="https://colab.research.google.com/github/nastaran-farhadi/Machine-learning-practice/blob/main/Multiple_linear_regression_House_Prices_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv('/content/gdrive/MyDrive/jadi/kc_house_data.csv')
dataset.head()

# %%
dataset.describe()

# %%
dataset.info()

# %%
#visualizing house prices
fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(dataset['price'])

# %%
fig.add_subplot(2,1,2)
sns.boxplot(dataset['price'])
plt.tight_layout()

# %%
from seaborn.relational import scatterplot
#visualizing square footage of (home,lot,above and basement)
fig = plt.figure(figsize=(16,5))
fig.add_subplot(2,2,1)
sns.scatterplot(data=dataset,x='sqft_above', y='price')
fig.add_subplot(2,2,2)
sns.scatterplot(data=dataset,x='sqft_lot',y='price')
fig.add_subplot(2,2,3)
sns.scatterplot(data=dataset,x='sqft_living',y='price')
fig.add_subplot(2,2,4)
sns.scatterplot(data=dataset,x='sqft_basement',y='price')

# %%
#visualizing bedrooms,bathrooms,floors,grade
fig = plt.figure(figsize=(15,7))
fig.add_subplot(2,2,1)
sns.countplot(x=dataset['bedrooms'])
fig.add_subplot(2,2,2)
sns.countplot(x=dataset['floors'])
fig.add_subplot(2,2,3)
sns.countplot(x=dataset['bathrooms'])
fig.add_subplot(2,2,4)
sns.countplot(x=dataset['grade'])
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
#let's break date to years, months
dataset['date'] = pd.to_datetime(dataset['date'])
dataset['month'] = dataset['date'].dt.month
dataset['year']=dataset['date'].dt.month
print(dataset.loc[:,['year']])

# %%
dataset=dataset.drop(['id','date','zipcode'],axis=1)

# %%
x=dataset.drop('price',axis=1)
type(x)

# %%
y=dataset.loc[:,['price']]

# %%
type(y)

# %%
y.head(10)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=101)

# %%
type(x_train)

# %%
type(y_train)

# %%
from sklearn.linear_model import LinearRegression
regr=LinearRegression()
regr.fit(x_train,y_train)
print(regr.coef_)
print(regr.intercept_)
